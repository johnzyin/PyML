# %% [markdown]
# # Python Numerical Tools
#
# ## 2. matplotlib
#
# ### An example

# %%
import numpy as np
import matplotlib.pyplot as plt

# Build a vector of 10000 normal deviates with variance 0.5^2 and mean 2
mu, sigma = 2, 0.5
v = np.random.normal(mu,sigma,10000)

# %%
# Compute the histogram with numpy and then plot it
(n, bins) = np.histogram(v, bins=50, density=True)  # NumPy version (no plot)
n
# Out:
# array([0.00256025, 0.        , 0.00128013, 0.00128013, 0.00256025,
#        0.00512051, 0.01280127, 0.01792178, 0.02688268, 0.04992497,
#        0.0512051 , 0.08704866, 0.10497045, 0.12673261, 0.17793771,
#        0.22786268, 0.27266714, 0.33795364, 0.45572536, 0.5043702 ,
#        0.66182587, 0.64774447, 0.71687135, 0.71303097, 0.79495912,
#        0.79623925, 0.81544116, 0.78215785, 0.67206689, 0.64518421,
#        0.56197593, 0.48260803, 0.47236701, 0.37635746, 0.3174716 ,
#        0.23938382, 0.18817873, 0.15617554, 0.09600956, 0.0652865 ,
#        0.04096408, 0.03328331, 0.01536153, 0.0140814 , 0.01280127,
#        0.00512051, 0.00512051, 0.00256025, 0.00256025, 0.00128013])

# %%
plt.plot(.5*(bins[1:]+bins[:-1]), n)
plt.show()

# %%
# Plot a normalized histogram with 50 bins
plt.hist(v, bins=50, density=1)       # matplotlib version (plot)
plt.show()
